# %%
from bs4 import BeautifulSoup
import pymysql
import requests
# import library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
sns.set_palette('Set3')

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["font.family"] = "NanumBarunGothic"

import re

# %%
# data load
# pip install openpyxl
path = "C:/k-디지털 프로젝트/2-Project/데이터"
# main = pd.read_excel(path + '/국립중앙도서관 대출 데이터/NL_CO_LOAN_PUB_202311-7.xlsx')
Top_Lib = pd.read_excel(path + '/크롤링select데이터/제목_ISBN중복제거(1).xlsx')



num_rows, num_columns = Top_Lib.shape

# 결과 출력
print(f"데이터 수: {num_rows}")

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
# Out:
# 데이터 수: 3235

# %%
conn = pymysql.connect(host='127.0.0.1',
                       user='root',
                       password='1234',
                       db='MyPRoj',
                       charset='utf8')
cursor = conn.cursor()

headers = {
   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

Book_count = 0

for index, count in Top_Lib.iterrows():
    response = requests.get("https://search.kyobobook.co.kr/search?keyword={0}&gbCode=TOT&target=total".format(count['ISBN13번호']), headers=headers)
        
    html = response.content.decode('utf-8','replace')
    soup = BeautifulSoup(html, 'html.parser',from_encoding='cp949')

    my_st = soup.select(
        '#shopData_list > ul > li > div.prod_area.horizontal > div.prod_info_box'
    )
    
    for stock_name in my_st:
        try:
            price_elements = stock_name.select("#shopData_list > ul > li > div.prod_area.horizontal > div.prod_info_box > div.prod_price > span.price > span.val")

            if price_elements and price_elements[0]:
                Book_Price = price_elements[0].text
                Price_varchar = Book_Price.replace(',','')
                print(Price_varchar)
                
            else:
                Book_Price = "0"

        except IndexError as e:
            print("Book_Price 처리 중 에러:", e)
            Book_Price = "0"

        
        try:
            Vente_exposant = stock_name.select("#shopData_list > ul > li > div.prod_area.horizontal > div.prod_info_box > div.prod_bottom > a > span.review_klover_box")
        
            if Vente_exposant and Vente_exposant[0]:
                Vente_exposant_text = Vente_exposant[0].text

                Vente_exposant_text_one = '%-11s' % (' ').join(Vente_exposant_text.split())
                matches = re.findall(r'[\d.]+', Vente_exposant_text_one)
                # print(Vente_exposant_text_one)
                ranking = matches[0]
            else:
                Vente_exposant_text = "0"

        except IndexError as e:
            print("review_desc 처리 중 에러:", e)
            Vente_exposant_text = "0"

        try:
            Vente_exposant = stock_name.select("#shopData_list > ul > li > div.prod_area.horizontal > div.prod_info_box > div.prod_bottom > a > span.review_klover_box")
        
            if Vente_exposant and Vente_exposant[0]:
                Vente_exposant_text = Vente_exposant[0].text

                Vente_exposant_text_one = '%-11s' % (' ').join(Vente_exposant_text.split())
                matches = re.findall(r'[\d.]+', Vente_exposant_text_one)
                # print(Vente_exposant_text_one)
                review_desc = matches[1]
            else:
                Vente_exposant_text = "0"

        except IndexError as e:
            print("review_desc 처리 중 에러:", e)
            Vente_exposant_text = "0"
       
    
    Book_count += 1
        # Replace '무료도서' with 0 for the 'price' column
    sql = "INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('{0}', {1}, {2}, {3});".format(str(count['ISBN13번호']),0 if Price_varchar == '무료도서' or Price_varchar == '절판되었습니다.' else int(Price_varchar) if Price_varchar is not None else 0,ranking, review_desc)
    print(Book_count, "/", {num_rows})
    print(sql)
    conn.commit()
    cursor.execute(sql)
# Out:
# 12600
# 1 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976934', 12600, 9.92, 51);
# 12600
# 2 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976927', 12600, 9.81, 50);
# 12600
# 3 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976910', 12600, 9.75, 51);
# 12600
# 4 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976903', 12600, 9.68, 57);
# 12600
# 5 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976897', 12600, 9.73, 74);
# 12600
# 6 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976880', 12600, 9.79, 85);
# 12600
# 7 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976873', 12600, 9.84, 94);
# 12600
# 8 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976866', 12600, 9.69, 109);
# 12600
# 9 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976859', 12600, 9.66, 171);
# 10 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976705', 12600, 9.57, 75);
# 16920
# 11 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976514', 16920, 9.52, 340);
# 12 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976484', 16920, 9.55, 33);
# 13320
# 13 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950976118', 13320, 9.79, 307);
# 14 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950975944', 13320, 9.79, 307);
# 18000
# 15 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950975913', 18000, 9.42, 341);
# 16 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950975739', 18000, 9.59, 154);
# 40500
# 17 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950975616', 40500, 9.63, 20);
# 8820
# 18 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950975562', 8820, 9.38, 17);
# 19 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950975524', 8820, 9.46, 194);
# 13320
# 20 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950974329', 13320, 9.69, 379);
# 11700
# 21 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950974305', 11700, 9.22, 29);
# 11700
# 22 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950974275', 11700, 9.4, 76);
# 23 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973766', 11700, 9.4, 76);
# 24 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973759', 11700, 9.4, 76);
# 10800
# 25 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973599', 10800, 10.0, 27);
# 26 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973353', 10800, 9.76, 393);
# 27 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973223', 10800, 9.54, 165);
# 28 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973025', 10800, 9.1, 391);
# 29 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950973018', 10800, 9.0, 166);
# 30 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971946', 10800, 9.67, 138);
# 13500
# 31 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971588', 13500, 9.9, 120);
# 13500
# 32 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971571', 13500, 9.92, 139);
# 13500
# 33 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971564', 13500, 9.82, 124);
# 13500
# 34 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971557', 13500, 9.94, 133);
# 13500
# 35 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971540', 13500, 9.95, 116);
# 13500
# 36 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971533', 13500, 9.93, 157);
# 13500
# 37 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971526', 13500, 9.92, 109);
# 13500
# 38 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971519', 13500, 9.87, 152);
# 13500
# 39 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971502', 13500, 9.92, 152);
# 13500
# 40 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971496', 13500, 9.86, 146);
# 13500
# 41 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971489', 13500, 9.83, 149);
# 13500
# 42 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971472', 13500, 9.96, 147);
# 13500
# 43 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971465', 13500, 9.93, 156);
# 13500
# 44 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971458', 13500, 9.9, 151);
# 13500
# 45 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971441', 13500, 9.95, 129);
# 13500
# 46 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971434', 13500, 9.91, 144);
# 13500
# 47 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971427', 13500, 9.84, 159);
# 13500
# 48 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971410', 13500, 9.85, 183);
# 13500
# 49 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971403', 13500, 9.87, 168);
# 13500
# 50 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971397', 13500, 9.73, 151);
# 13500
# 51 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971380', 13500, 9.87, 194);
# 13500
# 52 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971373', 13500, 9.88, 230);
# 13500
# 53 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971366', 13500, 9.79, 257);
# 54 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971359', 13500, 9.79, 257);
# 55 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950971144', 13500, 9.44, 5);
# 56 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950970888', 13500, 9.04, 238);
# 57 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950970765', 13500, 9.04, 238);
# 58 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950970758', 13500, 9.04, 238);
# 59 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950970741', 13500, 9.04, 238);
# 60 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950969905', 13500, 9.55, 60);
# 61 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950969783', 13500, 9.73, 78);
# 11700
# 62 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950969622', 11700, 9.8, 22);
# 12600
# 63 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950969615', 12600, 9.28, 22);
# 16200
# 64 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950969608', 16200, 9.35, 56);
# 65 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950969325', 16200, 9.57, 125);
# 66 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950968670', 16200, 9.72, 85);
# 67 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950967321', 16200, 9.68, 89);
# 68 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950967291', 16200, 9.68, 89);
# 69 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950967024', 16200, 9.78, 26);
# 70 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950966980', 16200, 9.78, 26);
# 71 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950966652', 16200, 9.15, 36);
# 72 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950966447', 16200, 9.53, 411);
# 17820
# 73 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950965693', 17820, 9.37, 921);
# 74 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950965471', 17820, 9.75, 86);
# 75 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950964948', 17820, 9.06, 149);
# 76 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950963613', 17820, 9.38, 239);
# 77 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950963477', 17820, 9.57, 63);
# 78 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950962869', 17820, 8.79, 151);
# 79 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950962746', 17820, 9.61, 48);
# 80 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950961435', 17820, 9.5, 43);
# 16200
# 81 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950961244', 16200, 9.24, 30);
# 82 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950960537', 16200, 9.46, 36);
# 83 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950957827', 16200, 9.82, 24);
# 84 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950956998', 16200, 9.01, 102);
# 85 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950956233', 16200, 10.0, 20);
# 86 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950955779', 16200, 9.32, 208);
# 87 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950954949', 16200, 9.53, 21);
# 88 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950952891', 16200, 8.48, 66);
# 89 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950952587', 16200, 9.79, 19);
# 90 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950950750', 16200, 9.42, 24);
# 91 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950949150', 16200, 9.24, 304);
# 92 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950949112', 16200, 9.66, 46);
# 93 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950948399', 16200, 8.75, 2);
# 94 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950948030', 16200, 9.88, 29);
# 95 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950945220', 16200, 10.0, 23);
# 96 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950939618', 16200, 10.0, 20);
# 97 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950937911', 16200, 10.0, 22);
# 98 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936358', 16200, 9.5, 25);
# 99 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936174', 16200, 9.69, 10);
# 100 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936167', 16200, 9.69, 11);
# 101 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936150', 16200, 10.0, 14);
# 102 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936143', 16200, 9.75, 12);
# 103 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936136', 16200, 9.9, 15);
# 104 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936129', 16200, 9.77, 14);
# 105 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936112', 16200, 9.88, 14);
# 106 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936105', 16200, 10.0, 12);
# 107 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936099', 16200, 9.69, 23);
# 108 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936082', 16200, 9.39, 18);
# 109 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936075', 16200, 9.67, 25);
# 110 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936068', 16200, 9.66, 33);
# 111 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936051', 16200, 9.21, 34);
# 112 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936044', 16200, 9.84, 40);
# 113 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936037', 16200, 9.58, 49);
# 114 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936020', 16200, 9.72, 47);
# 115 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936013', 16200, 9.48, 51);
# 116 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950936006', 16200, 9.4, 92);
# 117 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950935252', 16200, 10.0, 26);
# 118 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950929961', 16200, 6.68, 66);
# 119 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950926298', 16200, 8.48, 90);
# 120 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950925574', 16200, 8.48, 90);
# 8820
# 121 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950925369', 8820, 10.0, 5);
# 8820
# 122 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950925161', 8820, 0.0, 0);
# 123 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950925123', 8820, 10.0, 6);
# 124 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950921736', 8820, 10.0, 1);
# 8820
# 125 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950921729', 8820, 8.33, 3);
# 126 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950921712', 8820, 9.55, 10);
# 127 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950921705', 8820, 9.17, 3);
# 128 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950914943', 8820, 9.69, 8);
# 129 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950911546', 8820, 9.69, 8);
# 130 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950908584', 8820, 9.81, 21);
# 131 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950908560', 8820, 9.81, 21);
# 132 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950906610', 8820, 9.81, 21);
# 133 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950906085', 8820, 9.81, 21);
# 134 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950906078', 8820, 9.81, 21);
# 135 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950906061', 8820, 9.81, 21);
# 136 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950906054', 8820, 9.81, 21);
# 137 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950906047', 8820, 9.81, 21);
# 138 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788950905224', 8820, 9.81, 21);
# 25200
# 139 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949708850', 25200, 9.57, 60);
# 140 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949702926', 25200, 9.57, 60);
# 9000
# 141 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949197838', 9000, 9.74, 47);
# 9900
# 142 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949197821', 9900, 10.0, 55);
# 11700
# 143 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949197814', 11700, 9.79, 70);
# 9000
# 144 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195988', 9000, 9.58, 38);
# 145 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195971', 9000, 10.0, 7);
# 9000
# 146 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195964', 9000, 9.88, 45);
# 9000
# 147 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195896', 9000, 9.89, 42);
# 9000
# 148 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195889', 9000, 9.68, 42);
# 9000
# 149 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195872', 9000, 9.67, 32);
# 9000
# 150 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195865', 9000, 9.92, 33);
# 9000
# 151 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195858', 9000, 9.92, 36);
# 9900
# 152 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195841', 9900, 9.96, 41);
# 9900
# 153 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195834', 9900, 9.93, 43);
# 9900
# 154 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195827', 9900, 9.89, 43);
# 9000
# 155 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195810', 9000, 9.82, 62);
# 9000
# 156 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195797', 9000, 9.79, 56);
# 9000
# 157 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195780', 9000, 9.88, 48);
# 9900
# 158 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949195193', 9900, 9.56, 116);
# 6750
# 159 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194394', 6750, 8.44, 9);
# 6750
# 160 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194370', 6750, 10.0, 4);
# 6750
# 161 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194363', 6750, 9.69, 9);
# 6750
# 162 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194295', 6750, 8.41, 14);
# 6750
# 163 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194288', 6750, 10.0, 4);
# 6750
# 164 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194240', 6750, 10.0, 6);
# 6750
# 165 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194226', 6750, 9.58, 13);
# 6750
# 166 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949194219', 6750, 9.13, 23);
# 167 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949193786', 6750, 7.5, 1);
# 10800
# 168 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949192543', 10800, 9.92, 23);
# 169 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949191294', 10800, 10.0, 3);
# 13500
# 170 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949190020', 13500, 9.34, 757);
# 171 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949190013', 13500, 9.45, 59);
# 11700
# 172 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949189550', 11700, 9.83, 25);
# 16200
# 173 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949189543', 16200, 9.6, 149);
# 174 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949188553', 16200, 10.0, 4);
# 175 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949185323', 16200, 10.0, 11);
# 176 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949185026', 16200, 0.0, 0);
# 9900
# 177 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949182292', 9900, 9.0, 5);
# 178 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949181592', 9900, 8.85, 11);
# 179 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949179995', 9900, 8.85, 11);
# 9000
# 180 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949170626', 9000, 9.86, 12);
# 10800
# 181 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949162096', 10800, 9.7, 27);
# 9900
# 182 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949162072', 9900, 9.7, 73);
# 10800
# 183 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949162058', 10800, 9.86, 283);
# 10800
# 184 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949162041', 10800, 9.88, 335);
# 11700
# 185 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949162027', 11700, 9.69, 173);
# 10800
# 186 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949162003', 10800, 9.55, 18);
# 11700
# 187 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161983', 11700, 9.86, 47);
# 11700
# 188 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161969', 11700, 9.78, 356);
# 10800
# 189 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161952', 10800, 9.88, 24);
# 10800
# 190 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161945', 10800, 9.86, 94);
# 9900
# 191 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161860', 9900, 10.0, 12);
# 11700
# 192 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161846', 11700, 9.83, 71);
# 193 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161839', 11700, 9.66, 34);
# 8100
# 194 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161808', 8100, 9.46, 10);
# 10800
# 195 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161761', 10800, 9.75, 66);
# 9900
# 196 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161754', 9900, 9.69, 14);
# 9900
# 197 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161730', 9900, 9.79, 17);
# 8550
# 198 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161693', 8550, 9.9, 19);
# 7650
# 199 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161686', 7650, 10.0, 5);
# 9900
# 200 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161679', 9900, 10.0, 5);
# 8100
# 201 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161662', 8100, 10.0, 15);
# 8100
# 202 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161655', 8100, 9.17, 6);
# 9900
# 203 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161648', 9900, 9.55, 32);
# 204 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161556', 9900, 8.64, 11);
# 205 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161549', 9900, 9.29, 7);
# 206 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161532', 9900, 0.0, 0);
# 10800
# 207 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161495', 10800, 9.66, 40);
# 8100
# 208 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161488', 8100, 10.0, 9);
# 209 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161426', 8100, 0.0, 0);
# 10800
# 210 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161341', 10800, 9.82, 611);
# 9000
# 211 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161280', 9000, 9.17, 3);
# 9000
# 212 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161273', 9000, 9.58, 5);
# 9000
# 213 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161259', 9000, 10.0, 9);
# 8100
# 214 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161242', 8100, 9.17, 9);
# 7650
# 215 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161174', 7650, 9.57, 17);
# 7200
# 216 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161099', 7200, 10.0, 5);
# 8100
# 217 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161082', 8100, 10.0, 3);
# 8100
# 218 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161075', 8100, 10.0, 3);
# 8100
# 219 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161068', 8100, 9.76, 16);
# 7650
# 220 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161037', 7650, 9.17, 3);
# 9000
# 221 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949161020', 9000, 9.79, 7);
# 8100
# 222 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160986', 8100, 9.29, 4);
# 7650
# 223 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160900', 7650, 10.0, 5);
# 9000
# 224 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160757', 9000, 6.88, 3);
# 7200
# 225 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160658', 7200, 7.5, 2);
# 7200
# 226 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160504', 7200, 10.0, 2);
# 227 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160368', 7200, 9.7, 43);
# 9000
# 228 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160306', 9000, 10.0, 2);
# 229 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160078', 9000, 10.0, 5);
# 9000
# 230 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949160047', 9000, 9.11, 8);
# 231 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949159966', 9000, 9.11, 8);
# 232 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949159959', 9000, 9.11, 8);
# 233 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949159867', 9000, 9.11, 8);
# 25200
# 234 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949152936', 25200, 10.0, 20);
# 25200
# 235 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949151335', 25200, 10.0, 16);
# 236 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949150567', 25200, 8.33, 3);
# 237 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949150550', 25200, 9.47, 14);
# 10800
# 238 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949144030', 10800, 10.0, 12);
# 10800
# 239 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949144023', 10800, 10.0, 16);
# 10800
# 240 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949144016', 10800, 10.0, 28);
# 19800
# 241 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949141121', 19800, 9.87, 37);
# 10800
# 242 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949141084', 10800, 10.0, 17);
# 10800
# 243 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949140780', 10800, 9.58, 17);
# 244 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949140490', 10800, 9.65, 101);
# 11700
# 245 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949140254', 11700, 9.86, 48);
# 246 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949140247', 11700, 9.6, 18);
# 12600
# 247 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949140070', 12600, 9.68, 40);
# 11700
# 248 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949137001', 11700, 9.62, 27);
# 14400
# 249 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949135137', 14400, 10.0, 8);
# 14400
# 250 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949135120', 14400, 9.8, 23);
# 16200
# 251 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949135106', 16200, 9.59, 50);
# 11700
# 252 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949135021', 11700, 9.53, 10);
# 11700
# 253 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949135014', 11700, 9.86, 26);
# 254 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949130910', 11700, 8.93, 21);
# 9000
# 255 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124568', 9000, 10.0, 2);
# 10800
# 256 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124537', 10800, 9.92, 36);
# 9000
# 257 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124506', 9000, 9.89, 24);
# 9900
# 258 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124490', 9900, 10.0, 26);
# 9900
# 259 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124483', 9900, 9.87, 39);
# 260 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124476', 9900, 9.87, 39);
# 11700
# 261 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124445', 11700, 9.89, 38);
# 9900
# 262 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124438', 9900, 9.79, 37);
# 9000
# 263 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124421', 9000, 9.92, 86);
# 9000
# 264 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124407', 9000, 9.63, 22);
# 9000
# 265 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124384', 9000, 9.74, 51);
# 9900
# 266 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124360', 9900, 9.68, 51);
# 11700
# 267 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124353', 11700, 9.73, 135);
# 9000
# 268 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124339', 9000, 9.67, 15);
# 10800
# 269 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124322', 10800, 9.6, 34);
# 8550
# 270 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124308', 8550, 10.0, 2);
# 8100
# 271 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124223', 8100, 10.0, 7);
# 10800
# 272 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949124216', 10800, 9.64, 24);
# 13500
# 273 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949123493', 13500, 9.79, 279);
# 9900
# 274 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949123288', 9900, 8.94, 26);
# 11700
# 275 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949123141', 11700, 9.19, 89);
# 12600
# 276 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121857', 12600, 9.83, 120);
# 11700
# 277 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121840', 11700, 9.84, 53);
# 11700
# 278 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121819', 11700, 9.91, 133);
# 10800
# 279 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121727', 10800, 9.67, 49);
# 11700
# 280 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121697', 11700, 9.81, 38);
# 10800
# 281 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121598', 10800, 9.8, 36);
# 10800
# 282 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121543', 10800, 9.38, 47);
# 10800
# 283 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121482', 10800, 10.0, 30);
# 13500
# 284 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949121338', 13500, 9.75, 179);
# 12600
# 285 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949120768', 12600, 9.51, 68);
# 12600
# 286 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949120744', 12600, 9.63, 471);
# 11700
# 287 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949120720', 11700, 9.74, 15);
# 288 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949120232', 11700, 8.25, 8);
# 11700
# 289 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949118567', 11700, 10.0, 18);
# 11700
# 290 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949114057', 11700, 9.77, 11);
# 15300
# 291 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949114019', 15300, 10.0, 21);
# 11700
# 292 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949114002', 11700, 10.0, 5);
# 11700
# 293 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113982', 11700, 9.84, 18);
# 12600
# 294 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113975', 12600, 9.5, 4);
# 15300
# 295 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113951', 15300, 9.8, 22);
# 11700
# 296 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113944', 11700, 8.67, 27);
# 10800
# 297 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113807', 10800, 10.0, 4);
# 11700
# 298 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113791', 11700, 8.89, 7);
# 12600
# 299 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113784', 12600, 10.0, 4);
# 12600
# 300 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113760', 12600, 9.75, 70);
# 11700
# 301 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113739', 11700, 8.61, 5);
# 11700
# 302 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113692', 11700, 9.57, 40);
# 9900
# 303 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113678', 9900, 9.64, 18);
# 13500
# 304 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113647', 13500, 9.4, 25);
# 11700
# 305 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113623', 11700, 9.44, 46);
# 306 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949113609', 11700, 9.27, 36);
# 11700
# 307 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112763', 11700, 8.85, 12);
# 9900
# 308 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112732', 9900, 10.0, 6);
# 309 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112688', 9900, 10.0, 9);
# 11700
# 310 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112664', 11700, 10.0, 14);
# 12600
# 311 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112657', 12600, 9.51, 73);
# 10800
# 312 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112633', 10800, 9.89, 18);
# 11700
# 313 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112626', 11700, 9.34, 60);
# 11700
# 314 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112619', 11700, 9.58, 27);
# 315 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112596', 11700, 9.58, 27);
# 11700
# 316 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112541', 11700, 9.69, 14);
# 10800
# 317 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112534', 10800, 9.72, 8);
# 11700
# 318 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112510', 11700, 9.89, 19);
# 12600
# 319 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112503', 12600, 9.33, 37);
# 10800
# 320 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112480', 10800, 9.42, 26);
# 11700
# 321 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112459', 11700, 9.61, 19);
# 10800
# 322 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112428', 10800, 9.17, 28);
# 18000
# 323 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112350', 18000, 9.59, 35);
# 11700
# 324 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112312', 11700, 9.46, 20);
# 10800
# 325 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112282', 10800, 9.09, 10);
# 9000
# 326 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112251', 9000, 8.25, 10);
# 11700
# 327 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112206', 11700, 10.0, 6);
# 11700
# 328 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112183', 11700, 9.67, 20);
# 11700
# 329 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112138', 11700, 9.52, 18);
# 330 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112084', 11700, 9.52, 18);
# 20700
# 331 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112077', 20700, 9.64, 21);
# 10800
# 332 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112053', 10800, 9.81, 96);
# 11700
# 333 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949112008', 11700, 10.0, 5);
# 10800
# 334 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949111926', 10800, 8.75, 4);
# 11700
# 335 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788949111902', 11700, 10.0, 2);
# 10800
# 336 / 10100
# ...
# 9000
# 3124 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901082356', 9000, 9.32, 8);
# 12150
# 3125 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901079639', 12150, 8.19, 90);
# 8100
# 3126 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901079189', 8100, 10.0, 2);
# 3127 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901077796', 8100, 0.0, 0);
# 3128 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901077789', 8100, 0.0, 0);
# 3129 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901074597', 8100, 10.0, 2);
# 11700
# 3130 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901074405', 11700, 9.68, 38);
# 3131 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901072869', 11700, 10.0, 1);
# 9900
# 3132 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901071695', 9900, 9.87, 18);
# 3133 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901068701', 9900, 9.58, 5);
# 8550
# 3134 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901068602', 8550, 9.44, 27);
# 10800
# 3135 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901068381', 10800, 8.99, 78);
# 3136 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901066905', 10800, 8.99, 78);
# 3137 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901066608', 10800, 8.99, 78);
# 12420
# 3138 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901065229', 12420, 8.93, 42);
# 10800
# 3139 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901064208', 10800, 9.04, 13);
# 9900
# 3140 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901062921', 9900, 9.69, 7);
# 3141 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901061641', 9900, 8.13, 8);
# 3142 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901061238', 9900, 8.13, 8);
# 9900
# 3143 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901060316', 9900, 9.35, 67);
# 9900
# 3144 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901055190', 9900, 10.0, 23);
# 3145 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054957', 9900, 10.0, 23);
# 3146 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054940', 9900, 10.0, 23);
# 3147 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054926', 9900, 10.0, 23);
# 3148 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054889', 9900, 8.77, 312);
# 3149 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054179', 9900, 8.77, 312);
# 3150 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054162', 9900, 8.77, 312);
# 3151 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054148', 9900, 8.77, 312);
# 3152 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901054131', 9900, 8.77, 312);
# 3153 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901052960', 9900, 9.29, 6);
# 9000
# 3154 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901052922', 9000, 9.39, 135);
# 3155 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901051673', 9000, 9.39, 135);
# 3156 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901051260', 9000, 9.39, 135);
# 3157 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901050171', 9000, 9.39, 135);
# 10800
# 3158 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901049038', 10800, 9.32, 16);
# 11700
# 3159 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901047904', 11700, 9.78, 110);
# 3160 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901042350', 11700, 0.0, 0);
# 10800
# 3161 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901036373', 10800, 9.59, 39);
# 9900
# 3162 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901034379', 9900, 9.17, 7);
# 9900
# 3163 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901033518', 9900, 9.61, 227);
# 3164 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901033464', 9900, 8.33, 10);
# 9900
# 3165 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901029153', 9900, 9.43, 37);
# 11700
# 3166 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901028293', 11700, 9.81, 9);
# 3167 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901026978', 11700, 9.81, 9);
# 8100
# 3168 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901026329', 8100, 10.0, 6);
# 3169 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901024684', 8100, 10.0, 1);
# 3170 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9788901010601', 8100, 6.67, 3);
# 297000
# 3171 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9783836550376', 297000, 0.0, 0);
# 36190
# 3172 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9782070632855', 36190, 0.0, 0);
# 35420
# 3173 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9782070624805', 35420, 0.0, 0);
# 3174 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781846438073', 35420, 0.0, 0);
# 8100
# 3175 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781846438042', 8100, 0.0, 0);
# 3176 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781788100823', 8100, 0.0, 0);
# 3177 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781788100793', 8100, 0.0, 0);
# 11670
# 3178 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781788005418', 11670, 0.0, 0);
# 11670
# 3179 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781783708727', 11670, 0.0, 0);
# 3180 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781782701897', 11670, 0.0, 0);
# 3181 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781740897174', 11670, 0.0, 0);
# 7650
# 3182 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781646862238', 7650, 0.0, 0);
# 7200
# 3183 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781646860494', 7200, 0.0, 0);
# 11780
# 3184 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781534424746', 11780, 0.0, 0);
# 3185 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781482402155', 11780, 0.0, 0);
# 11670
# 3186 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781471171703', 11670, 0.0, 0);
# 3187 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781409530220', 11670, 0.0, 0);
# 3188 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781406344530', 11670, 0.0, 0);
# 9600
# 3189 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781406313574', 9600, 10.0, 2);
# 12740
# 3190 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781338323214', 12740, 9.87, 12);
# 7140
# 3191 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781338298697', 7140, 0.0, 0);
# 34030
# 3192 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9781101937914', 34030, 0.0, 0);
# 3193 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780805087987', 34030, 0.0, 0);
# 3194 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780723249993', 34030, 0.0, 0);
# 7600
# 3195 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780698115637', 7600, 9.0, 3);
# 7200
# 3196 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780689862953', 7200, 10.0, 4);
# 3197 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780689836930', 7200, 10.0, 4);
# 4600
# 3198 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679883388', 4600, 10.0, 2);
# 3199 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679863748', 4600, 10.0, 5);
# 4580
# 3200 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679863731', 4580, 10.0, 3);
# 5920
# 3201 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679863724', 5920, 10.0, 1);
# 6540
# 3202 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679844075', 6540, 0.0, 0);
# 3850
# 3203 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679826422', 3850, 5.0, 1);
# 7740
# 3204 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679824244', 7740, 9.55, 9);
# 7280
# 3205 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679824121', 7280, 8.82, 15);
# 5550
# 3206 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780679824114', 5550, 9.74, 31);
# 6500
# 3207 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780590353427', 6500, 9.3, 78);
# 3208 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780545311595', 6500, 9.3, 78);
# 3209 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780545311441', 6500, 9.3, 78);
# 5950
# 3210 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780448412603', 5950, 10.0, 1);
# 8550
# 3211 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780374468620', 8550, 10.0, 2);
# 22260
# 3212 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780374308131', 22260, 0.0, 0);
# 10470
# 3213 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780316478939', 10470, 0.0, 0);
# 21980
# 3214 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780316316002', 21980, 0.0, 0);
# 3215 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780316315975', 21980, 0.0, 0);
# 11760
# 3216 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780316236539', 11760, 10.0, 2);
# 3217 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780230760356', 11760, 10.0, 2);
# 8850
# 3218 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780198489191', 8850, 0.0, 0);
# 13530
# 3219 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780198483458', 13530, 0.0, 0);
# 8850
# 3220 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780198481379', 8850, 0.0, 0);
# 3221 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780198468745', 8850, 0.0, 0);
# 3222 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780198465393', 8850, 0.0, 0);
# 3223 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780198464327', 8850, 0.0, 0);
# 3224 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780141371481', 8850, 0.0, 0);
# 3225 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780141371443', 8850, 0.0, 0);
# 3226 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780141371375', 8850, 0.0, 0);
# 3227 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780141349961', 8850, 0.0, 0);
# 8000
# 3228 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780064431910', 8000, 0.0, 0);
# 7170
# 3229 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780064430173', 7170, 8.33, 2);
# 24880
# 3230 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780062954527', 24880, 0.0, 0);
# 26190
# 3231 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('9780062866004', 26190, 0.0, 0);
# 3232 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('8809462436400', 26190, 0.0, 0);
# 무료도서
# 3233 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('6666666666666', 0, 0.0, 0);
# 3234 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('2222222222222', 0, 0.0, 0);
# 3235 / 10100
# INSERT INTO MyPRoj.Book_Review (ISBN_THIRTEEN_NO, price, Vente_exposant, review_desc) VALUES('1727101922213', 0, 0.0, 0);
