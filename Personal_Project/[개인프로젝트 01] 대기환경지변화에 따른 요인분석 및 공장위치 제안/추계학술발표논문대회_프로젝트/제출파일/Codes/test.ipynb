# %%
import requests as rq

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
params = {'serviceKey' : '86q7nqQ+pf+EUZng6XiW9lsc+PLLoMPDHOWl3nJ11A18kVDYtInW3fUuJTl2UGxisQKOjqJPPLfuhBC7tm90Vg==' ,
          'returnType' : 'json' ,
          'numOfRows' : '1000' ,
          'pageNo' : '1' ,
          'sidoName' : '서울' ,
          'ver' : '1.0'
          }

response = rq.get(url , params = params)
response
# Out:
# <Response [200]>

# %%
url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth '
params = {
    'serviceKey' : '86q7nqQ+pf+EUZng6XiW9lsc+PLLoMPDHOWl3nJ11A18kVDYtInW3fUuJTl2UGxisQKOjqJPPLfuhBC7tm90Vg==' ,
    'returnType' : 'json' ,
    'searchDate' : '2024-04-14' ,
    'InformCode' : 'PM10'
}

response = rq.get(url , params = params)
response
# Out:
# <Response [500]>

# %%
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">\n    <soapenv:Body>\n        <soapenv:Fault>\n            <faultcode>soapenv:Server</faultcode>\n            <faultstring>Policy Falsified</faultstring>\n            <faultactor>http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth%20?serviceKey=86q7nqQ%2Bpf%2BEUZng6XiW9lsc%2BPLLoMPDHOWl3nJ11A18kVDYtInW3fUuJTl2UGxisQKOjqJPPLfuhBC7tm90Vg%3D%3D&amp;returnType=json&amp;searchDate=2024-04-14&amp;InformCode=PM10</faultactor>\n            <detail>\n                <l7:policyResult\n                    status="Service Not Found.  The request may have been sent to an invalid URL, or intended for an unsupported operation." xmlns:l7="http://www.layer7tech.com/ws/policy/fault"/>\n            </detail>\n        </soapenv:Fault>\n    </soapenv:Body>\n</soapenv:Envelope>\n'

# %%
api_url = 'https://air-quality-api.open-meteo.com/v1/air-quality?latitude=36.8&longitude=127.0769&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,ozone'
